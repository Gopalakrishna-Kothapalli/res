# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

baseurl = "https://www.thewhiskyexchange.com"

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'}
productlinks = []
t={}
data=[]
c=0
for x in range(1,6):
    k = requests.get('https://www.thewhiskyexchange.com/c/35/japanese-whisky?pg={}&psize=24&sort=pasc'.format(x)).text
    soup=BeautifulSoup(k,'html.parser')
    productlist = soup.find_all("li",{"class":"product-grid__item"})


    for product in productlist:
        link = product.find("a",{"class":"product-card"}).get('href')
        productlinks.append(baseurl + link)


for link in productlinks:
    f = requests.get(link,headers=headers).text
    hun=BeautifulSoup(f,'html.parser')

    try:
        price=hun.find("p",{"class":"product-action__price"}).text.replace('\n',"")
    except:
        price = None

    try:
        about=hun.find("div",{"class":"product-main__description"}).text.replace('\n',"")
    except:
        about=None

    try:
        rating = hun.find("div",{"class":"review-overview"}).text.replace('\n',"")
    except:
        rating=None

    try:
        name=hun.find("h1",{"class":"product-main__name"}).text.replace('\n',"")
    except:
        name=None

    whisky = {"name":name,"price":price,"rating":rating,"about":about}

    data.append(whisky)
    c=c+1
    print("completed",c)

df = pd.DataFrame(data)

print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests
from bs4 import BeautifulSoup
 
 
url = 'https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=6a8e020c-02f6-449a-a556-28d3f24c8b77&as-backfill=on'
reqs = requests.get(url)
soup = BeautifulSoup(reqs.text, 'html.parser')
 
urls = []
count=0
for link in soup.find_all('a'):
    count+=1
    # print(link.get('href'))
    urls.append(link.get('href'))
print(count)
with open('urls.txt', 'w') as f:
    for item in urls:
        f.write("%s\n" % item)
# Out:
# 78

# %%
import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent

def get_amazon_link(product_name):
    base_url = f'https://www.amazon.com/s?k={product_name.replace(" ", "+")}'
    
    headers = {
        'User-Agent': UserAgent().random
    }

    response = requests.get(base_url, headers=headers)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        first_result = soup.find('a', {'class': 's-no-outline'}, href=True)

        if first_result:
            href = first_result['href']
            full_link = 'https://www.amazon.com' + href
            return full_link

    return None

# Example usage
laptop_names = [
    'Lenovo IdeaPad Slim 5 Intel Core i5 11th Gen 15.6" (39.62cm) FHD IPS Thin & Light Laptop (16GB/512GB SSD/Windows 11/Office 2021/Backlit/FPR/3months Game Pass/Graphite Grey/1.66Kg), 82FG01H9IN',
    'MacBook Air',
    'HP Spectre x360',
    # Add more laptop names to the list
]

for laptop_name in laptop_names:
    link = get_amazon_link(laptop_name)
    if link:
        print(f"{laptop_name}: {link}")
    else:
        print(f"No result found for {laptop_name}")
# Out:
# Lenovo IdeaPad Slim 5 Intel Core i5 11th Gen 15.6" (39.62cm) FHD IPS Thin & Light Laptop (16GB/512GB SSD/Windows 11/Office 2021/Backlit/FPR/3months Game Pass/Graphite Grey/1.66Kg), 82FG01H9IN: https://www.amazon.com/sspa/click?ie=UTF8&spc=MTo3OTY4NTY3NjU0NDEwMDQ6MTcwNDQ0NjQ0OTpzcF9hdGY6MjAwMTIzOTU5NTA1Mjk4OjowOjo&url=%2FLenovo-2023-Laptop-FHD-HubxcelAccessory%2Fdp%2FB0BSZW4VNT%2Fref%3Dsr_1_1_sspa%3Fkeywords%3DLenovo%2BIdeaPad%2BSlim%2B5%2BIntel%2BCore%2Bi5%2B11th%2BGen%2B15.6%2522%2B%252839.62cm%2529%2BFHD%2BIPS%2BThin%26qid%3D1704446449%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1
# No result found for MacBook Air
# No result found for HP Spectre x360

# %%
from googlesearch import search

def get_google_results(query, num_results=5):
    results = []
    try:
        for result in search(query, num_results=num_results):
            results.append(result)
    except Exception as e:
        print(f"Error: {e}")
    return results

# Example usage
laptop_names = [
    'Dell XPS 13',
    'MacBook Air',
    'HP Spectre x360',
    'Lenovo IdeaPad Slim 5'
]

for laptop_name in laptop_names:
    print(f"\nSearching for {laptop_name}...")
    google_results = get_google_results(laptop_name, num_results=1)

    if google_results:
        print(f"Result: {google_results[0]}")
    else:
        print(f"No result found for {laptop_name}")
# Out:
# Searching for Dell XPS 13...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 22
#      20 for laptop_name in laptop_names:
#      21     print(f"\nSearching for {laptop_name}...")
# ---> 22     google_results = get_google_results(laptop_name, num_results=1)
#      24     if google_results:
#      25         print(f"Result: {google_results[0]}")
#
# Cell In[24], line 6, in get_google_results(query, num_results)
#       4 results = []
#       5 try:
# ----> 6     for result in search(query, num_results=num_results):
#       7         results.append(result)
#       8 except Exception as e:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\googlesearch\__init__.py:54, in search(term, num_results, lang, proxy, advanced, sleep_interval, timeout)
#      51 start = 0
#      52 while start < num_results:
#      53     # Send request
# ...

# %%
from bs4 import BeautifulSoup
import requests

# Function to extract Product Title
def get_title(soup):
	
	try:
		# Outer Tag Object
		title = soup.find("span", attrs={"id":'productTitle'})

		# Inner NavigatableString Object
		title_value = title.string

		# Title as a string value
		title_string = title_value.strip()

		# # Printing types of values for efficient understanding
		# print(type(title))
		# print(type(title_value))
		# print(type(title_string))
		# print()

	except AttributeError:
		title_string = ""	

	return title_string

# Function to extract Product Price
def get_price(soup):

	try:
		price = soup.find("span", attrs={'id':'priceblock_ourprice'}).string.strip()

	except AttributeError:

		try:
			# If there is some deal price
			price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()

		except:		
			price = ""	

	return price

# Function to extract Product Rating
def get_rating(soup):

	try:
		rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
		
	except AttributeError:
		
		try:
			rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
		except:
			rating = ""	

	return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
	try:
		review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()
		
	except AttributeError:
		review_count = ""	

	return review_count

# Function to extract Availability Status
def get_availability(soup):
	try:
		available = soup.find("div", attrs={'id':'availability'})
		available = available.find("span").string.strip()

	except AttributeError:
		available = "Not Available"	

	return available	


if __name__ == '__main__':

	# Headers for request
	HEADERS = ({'User-Agent':
	            'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
	            'Accept-Language': 'en-US'})

	# The webpage URL
	URL = "https://www.amazon.com/s?k=playstation+4&ref=nb_sb_noss_2"
	
	# HTTP Request
	webpage = requests.get(URL, headers=HEADERS)

	# Soup Object containing all data
	soup = BeautifulSoup(webpage.content, "lxml")

	# Fetch links as List of Tag Objects
	links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})

	# Store the links
	links_list = []

	# Loop for extracting links from Tag Objects
	for link in links:
		links_list.append(link.get('href'))


	# Loop for extracting product details from each link 
	for link in links_list:

		new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)

		new_soup = BeautifulSoup(new_webpage.content, "lxml")
		
		# Function calls to display all necessary product information
		print("Product Title =", get_title(new_soup))
		print("Product Price =", get_price(new_soup))
		print("Product Rating =", get_rating(new_soup))
		print("Number of Product Reviews =", get_review_count(new_soup))
		print("Availability =", get_availability(new_soup))
		print()
		print()
# Out:
# Product Title =
# Product Price =
# Product Rating =
# Number of Product Reviews =
# Availability = Not Available
#
#
# Product Title =
# Product Price =
# Product Rating =
# Number of Product Reviews =
# Availability = Not Available
#
#
# Product Title = Among Us: Ejected Edition (PS4) - PlayStation 4
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 40 ratings
# Availability = Not Available
#
#
# Product Title = PlayStation®4 Console – Call of Duty® Modern Warfare II Bundle
# Product Price =
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 26 ratings
# Availability = Not Available
#
#
# Product Title =
# Product Price =
# Product Rating =
# Number of Product Reviews =
# Availability = Not Available
#
#
# Product Title = Sony PlayStation 4 500GB Console - Black
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 3,355 ratings
# Availability = Only 2 left in stock - order soon.
#
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent

def get_amazon_links(category='laptop', num_pages=5):
    base_url = f'https://www.amazon.com/s?k={category}&page='
    all_links = []

    headers = {
        'User-Agent': UserAgent().random
    }

    for page in range(1, num_pages + 1):
        url = base_url + str(page)
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            links = soup.find_all('a', {'class': 's-no-outline'}, href=True)

            for link in links:
                href = link['href']
                if '/dp/' in href:
                    full_link = 'https://www.amazon.in' + href
                    all_links.append(full_link)

    return all_links

# Example usage
laptop_links = get_amazon_links(category='laptops', num_pages=3)
for link in laptop_links:
    print(link)

# %%
import requests
from bs4 import BeautifulSoup

def getLink(product_name, num_results=1):
    base_url = f'https://www.flipkart.com/search?q={product_name.replace(" ", "+")}&page='
    all_links = []

    for page in range(1, num_results + 1):
        url = base_url + str(page)
        response = requests.get(url)

        if response.status_code == 200:
            try:
                soup = BeautifulSoup(response.text, 'html.parser')
                link = soup.find('a', {'class': '_1fQZEK'}, href=True)
                href = link['href']
                full_link = 'https://www.flipkart.com' + href
                return full_link
            except:
                return None

    return None

# Example usage
product_name = "Dell XPS 13 laptop"
flipkart_links = getLink(product_name, num_results=1)

print(flipkart_links)
# Out:
# https://www.flipkart.com/dell-xps-intel-core-i5-10th-gen-1035g1-8-gb-512-gb-ssd-windows-10-home-9300-thin-light-laptop/p/itmbdb9070446946?pid=COMFTC4YBSK8WZQC&lid=LSTCOMFTC4YBSK8WZQCPSGZIJ&marketplace=FLIPKART&q=Dell+XPS+13+laptop&store=6bo%2Fb5g&srno=s_1_1&otracker=search&fm=organic&iid=d8a07acf-9ea1-481e-8083-e2ae6679692b.COMFTC4YBSK8WZQC.SEARCH&ppt=None&ppn=None&ssid=5hsbm2ka8w0000001704463555864&qH=a6222649d8e1e00c

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
from tqdm import tqdm

# %%
df = pd.read_csv('Cleaned_Laptop_data.csv')

# %%
df.head()
# Out:
#     brand    model processor_brand     processor_name processor_gnrtn  \
# 0  Lenovo  A6-9225             AMD  A6-9225 Processor            10th
# 1  Lenovo  Ideapad             AMD           APU Dual            10th
# 2   Avita     PURA             AMD           APU Dual            10th
# 3   Avita     PURA             AMD           APU Dual            10th
# 4   Avita     PURA             AMD           APU Dual            10th
#
#     ram_gb ram_type     ssd      hdd       os  ... display_size  warranty  \
# 0  4 GB GB     DDR4    0 GB  1024 GB  Windows  ...      Missing         0
# 1  4 GB GB     DDR4    0 GB   512 GB  Windows  ...      Missing         0
# 2  4 GB GB     DDR4  128 GB     0 GB  Windows  ...      Missing         0
# 3  4 GB GB     DDR4  128 GB     0 GB  Windows  ...      Missing         0
# 4  4 GB GB     DDR4  256 GB     0 GB  Windows  ...      Missing         0
#
#   Touchscreen msoffice  latest_price old_price discount  star_rating  ratings  \
# ...

# %%
# df['link']=np.nan
for i in tqdm(range(len(df))):
    product_name = df.loc[i,'brand'] + ' ' + df.loc[i,'model'] + ' ' + df.loc[i,'processor_brand'] + ' ' + df.loc[i,'processor_name'] + ' ' + df.loc[i,'processor_gnrtn'] + ' ' + df.loc[i,'ram_type']
    if df.iloc[i]['link'] != 'Not Found':
        continue
    link = getLink(product_name)
    if(link):
        df.loc[i,'link'] = link
    else:
        df.loc[i,'link'] = 'Not Found'
# Out:
# 100%|██████████| 896/896 [01:22<00:00, 10.82it/s]

# %%
count = 0
found = 0
for i in tqdm(range(len(df))):
    # link = getLink(product_name)
    if df.loc[i,'link'] == 'Not Found':
        count+=1
    else:
        found+=1

print(f'Found {found} links')
print(f'Not Found {count} links')


# save the dataframe
df.to_csv('cleaned_laptops_updated.csv',index=False)
# Out:
# 100%|██████████| 896/896 [00:00<00:00, 138885.26it/s]
# Found 790 links
# Not Found 106 links

# %%
import requests
from bs4 import BeautifulSoup

def get_amazon_link(product_name, num_results=1):
    base_url = f'https://www.amazon.com/s?k={product_name.replace(" ", "+")}&page='

    for page in range(1, num_results + 1):
        url = base_url + str(page)
        response = requests.get(url)

        if response.status_code == 200:
            try:
                soup = BeautifulSoup(response.text, 'html.parser')
                link = soup.find('a', {'class': 'a-link-normal'}, href=True)
                href = link['href']
                full_link = 'https://www.amazon.com' + href
                return full_link
            except:
                return None

    return None

# Example usage
product_name = "Lenovo IdeaPad Slim 5 Intel Core i5"
amazon_link = get_amazon_link(product_name, num_results=1)

print(amazon_link)
# Out:
# None
