# %%
import pandas as pd
import numpy as np

# %%
laptops = pd.read_csv("cleaned_laptops_final.csv", encoding="Latin-1")

# %%
laptops.head()
# Out:
#     brand    model processor_brand     processor_name processor_gnrtn  ram_gb  \
# 0  Lenovo  A6-9225             AMD  A6-9225 Processor            10th       4
# 1  Lenovo  Ideapad             AMD           APU Dual            10th       4
# 2   Avita     PURA             AMD           APU Dual            10th       4
# 3   Avita     PURA             AMD           APU Dual            10th       4
# 4   Avita     PURA             AMD           APU Dual            10th       4
#
#   ram_type  ssd   hdd       os  ...  \
# 0     DDR4    0  1024  Windows  ...
# 1     DDR4    0   512  Windows  ...
# 2     DDR4  128     0  Windows  ...
# 3     DDR4  128     0  Windows  ...
# 4     DDR4  256     0  Windows  ...
#
#                                                 link  storage Studying  \
# 0  https://www.flipkart.com/lenovo-e41-amd-apu-du...     1024    False
# 1  https://www.flipkart.com/lenovo-ideapad-1-amd-...      512    False
# ...

# %%
# add a column "id" to the beginning of the dataframe
laptops.insert(0, "id", range(0, len(laptops)))

# %%
laptops.to_csv("cleaned_laptops_final.csv", index=False)
